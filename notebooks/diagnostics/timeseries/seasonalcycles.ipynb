# %% [markdown]
# # Seasonal cycles
#
# This notebook shows how to use the seasonal cycles diagnostic. Here we focus on the `SeasonalCycles` for the single model evaluation and the `PlotSeasonalCycles` for the multi model plots.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from aqua.diagnostics.timeseries import SeasonalCycles

# %%
dataset_dict = {'catalog': 'climatedt-phase1',
                'model': 'ICON',
                'exp': 'historical-1990',
                'source': 'lra-r100-monthly'}
obs_dict = {'catalog': 'obs',
            'model': 'ERA5',
            'exp': 'era5',
            'source': 'monthly',
            'std_startdate': '1990-01-01',
            'std_enddate': '1999-12-31'}
common_dict = {'startdate': '1990-01-01',
               'enddate': '1999-12-31',
               'loglevel': 'info'}

# %%
sc_dataset = SeasonalCycles(**dataset_dict, **common_dict)
# Out:
# 2026-01-29 16:04:21 :: Seasonalcycles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None

# %%
run_dict = {'var': '2t',
            'units': 'degC'}

# %%
sc_dataset.run(**run_dict)
# Out:
# 2026-01-29 16:04:21 :: Seasonalcycles :: INFO     -> Running SeasonalCycles for 2t
# 2026-01-29 16:04:21 :: ConfigPath :: INFO     -> ICON_historical-1990_lra-r100-monthly triplet found in in climatedt-phase1!
# 2026-01-29 16:04:22 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-01-29 16:04:22 :: FixerConfigure :: INFO     -> Fix names in metadata is icon-destine-v1-lra
# 2026-01-29 16:04:22 :: FixerConfigure :: INFO     -> Fix names icon-destine-v1-lra found in fixes files
# 2026-01-29 16:04:22 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-01-29 16:04:22 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-01-29 16:04:22 :: Reader :: WARNING  -> Issues in the Regridder() init: trying with data
# 2026-01-29 16:05:16 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-01-29 16:05:16 :: CoordIdentifier :: WARNING  -> Coordinate 'level' assigned to multiple types with identical scores: [('depth', 50), ('height', 50)]. Disabling data model check for this coordinate.
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: isobaric
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-01-29 16:05:16 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-01-29 16:05:16 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-01-29 16:05:16 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-01-29 16:05:16 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-01-29 16:05:16 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-01-29 16:05:16 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/aqua-dvc/areas/cell_area_ICON_historical-1990_lra-r100-monthly.nc.
# 2026-01-29 16:05:16 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-01-29 16:05:16 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-01-29 16:05:16 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2026-01-29 16:05:16 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2026-01-29 16:05:17 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2026-01-29 16:05:17 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-01-29 16:05:17 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-01-29 16:05:17 :: Seasonalcycles :: INFO     -> Computing the seasonal cycles
# 2026-01-29 16:05:17 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2026-01-29 16:05:17 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-01-29 16:05:17 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-01-29 16:05:17 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-01-29 16:05:18 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2026-01-29 16:05:18 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-01-29 16:05:19 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.2t.monthly.global.nc

# %%
sc_obs = SeasonalCycles(**obs_dict, **common_dict)
sc_obs.run(**run_dict, std=True)
# Out:
# 2026-01-29 16:05:19 :: Seasonalcycles :: INFO     -> No region provided, using lon_limits: None, lat_limits: None
# 2026-01-29 16:05:19 :: Seasonalcycles :: INFO     -> Running SeasonalCycles for 2t
# 2026-01-29 16:05:19 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2026-01-29 16:05:19 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-01-29 16:05:19 :: FixerConfigure :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2026-01-29 16:05:19 :: FixerConfigure :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2026-01-29 16:05:20 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2026-01-29 16:05:20 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2026-01-29 16:05:20 :: Regridder :: INFO     -> Loading existing source area from /pfs/lustrep3/appl/local/climatedt/data/AQUA/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2026-01-29 16:05:20 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-01-29 16:05:20 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-01-29 16:05:20 :: Reader :: INFO     -> Retrieving variables: ['2t']
# 2026-01-29 16:05:21 :: Fixer :: INFO     -> Variables to be fixed: {'2t': {'source': [167, 228004, '2t', 'mean2t', 'avg_2t', 'T2M', 'tas'], 'grib': 167}}
# 2026-01-29 16:05:21 :: Fixer :: INFO     -> 2t: converting units K --> K
# 2026-01-29 16:05:22 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-01-29 16:05:22 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-01-29 16:05:22 :: Seasonalcycles :: INFO     -> Computing monthly standard deviation
# 2026-01-29 16:05:22 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2026-01-29 16:05:22 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-01-29 16:05:22 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-01-29 16:05:22 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-01-29 16:05:29 :: Seasonalcycles :: INFO     -> Computing the seasonal cycles
# 2026-01-29 16:05:29 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2026-01-29 16:05:29 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-01-29 16:05:29 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-01-29 16:05:29 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-01-29 16:05:35 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2026-01-29 16:05:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-01-29 16:05:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.obs.ERA5.era5.r1.2t.monthly.global.nc
# 2026-01-29 16:05:35 :: Seasonalcycles :: INFO     -> Saving monthly data for seasonalcycles to netcdf in ./
# 2026-01-29 16:05:35 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-01-29 16:05:35 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/seasonalcycles.seasonalcycles.obs.ERA5.era5.r1.2t.monthly.global.std.nc

# %%
from aqua.diagnostics.timeseries import PlotSeasonalCycles

# %%
plot_dict = {'monthly_data': sc_dataset.monthly,
             'ref_monthly_data': sc_obs.monthly,
             'std_monthly_data': sc_obs.std_monthly,
             'loglevel': 'INFO'}

# %%
plot = PlotSeasonalCycles(**plot_dict)
data_labels = plot.set_data_labels()
ref_labels = plot.set_ref_label()
desc = plot.set_description()
title = plot.set_title()
fig, _ = plot.plot_seasonalcycles(data_labels=data_labels, ref_label=ref_labels, title=title)
plot.save_plot(fig=fig, description=desc)
# Out:
# 2026-01-29 16:05:55 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-01-29 16:05:56 :: add_png_metadata :: INFO     -> Metadata added to PNG: ./png/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
# 2026-01-29 16:05:56 :: OutputSaver :: INFO     -> Saved PNG: ./png/seasonalcycles.seasonalcycles.climatedt-phase1.ICON.historical-1990.r1.obs.ERA5.era5.2t.png
