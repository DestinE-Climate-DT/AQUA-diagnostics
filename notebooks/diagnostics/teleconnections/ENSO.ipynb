# %% [markdown]
# # ENSO example notebook
#
# This notebook contains an example of access of a dataset and ERA5 data and evaluation of the ENSO teleconnection and plot with the diagnostics part of the teleconnections module.
#
# The only import needed is the ENSO and PlotENSO classes from the `aqua.diagnostics.teleconnections` module

# %%
from aqua.diagnostics.teleconnections import ENSO, PlotENSO

# %matplotlib inline

# %% [markdown]
# # Evaluating ENSO
#
# To simplify the code below we set the two dataset we want to analyse as dictionary here. The syntax is the same as for the `Reader`.

# %%
dataset_dict = {
    "catalog": "climatedt-gen2",
    "model": "IFS-FESOM-5km",
    "exp": "baseline-hist",
    "source": "lra-r100-monthly",
}
obs_dict = {
    "catalog": "obs",
    "model": "ERA5",
    "exp": "era5",
    "source": "monthly",
}
common_dict = {"loglevel": "INFO"}

# %% [markdown]
# The initialization requires a minimal set of arguments. All other details can be set while calling the individual methods.
#
# Notice that an instance of the class is required for each dataset.

# %%
enso_dataset = ENSO(**dataset_dict, **common_dict)
enso_obs = ENSO(**obs_dict, **common_dict)

# %% [markdown]
# We first retrieve the data. The needed variable is deduced by the class and it can be modified with YAML file (see `/config/diagnostics/teleconnections/definitions/`)

# %%
enso_dataset.retrieve()
enso_obs.retrieve()
# Out:
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-07-24 14:24:23 :: ConfigPath :: INFO     -> IFS-FESOM-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-07-24 14:24:23 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-07-24 14:24:23 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-07-24 14:24:23 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-07-24 14:24:23 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-07-24 14:24:23 :: Reader :: INFO     -> Regridder() cannot init with the provided grid metadata: trying with data
# 2026-07-24 14:24:41 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-07-24 14:24:41 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-07-24 14:24:41 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-07-24 14:24:41 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-07-24 14:24:41 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-07-24 14:24:41 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-07-24 14:24:41 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-07-24 14:24:41 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-07-24 14:24:41 :: Reader :: INFO     -> Retrieving variables: ['tos']
# 2026-07-24 14:24:59 :: Fixer :: INFO     -> Variables to be fixed: {'tos': {'source': [34, 262101, 263101, 'avg_tos', 'sst', 'analysed_sst', 'SSTK', 'avg_sst', 'tos'], 'grib': 262101}}
# 2026-07-24 14:24:59 :: Fixer :: INFO     -> tos: converting units K --> K
# 2026-07-24 14:24:59 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-07-24 14:24:59 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-07-24 14:24:59 :: ENSO :: INFO     -> Start date: 1990-01-01
# 2026-07-24 14:24:59 :: ENSO :: INFO     -> End date: 2014-12-01
# 2026-07-24 14:24:59 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-07-24 14:25:00 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2026-07-24 14:25:00 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-07-24 14:25:00 :: FixerConfigure :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2026-07-24 14:25:00 :: FixerConfigure :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2026-07-24 14:25:00 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2026-07-24 14:25:00 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2026-07-24 14:25:00 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2026-07-24 14:25:00 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-07-24 14:25:00 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-07-24 14:25:00 :: Reader :: INFO     -> Retrieving variables: ['tos']
# 2026-07-24 14:25:01 :: Fixer :: INFO     -> Variables to be fixed: {'tos': {'source': [34, 262101, 263101, 'avg_tos', 'sst', 'analysed_sst', 'SSTK', 'avg_sst', 'tos'], 'grib': 262101}}
# 2026-07-24 14:25:01 :: Fixer :: INFO     -> tos: converting units K --> K
# 2026-07-24 14:25:01 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-07-24 14:25:01 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-07-24 14:25:01 :: ENSO :: INFO     -> Start date: 1940-01-01
# 2026-07-24 14:25:01 :: ENSO :: INFO     -> End date: 2024-12-01
# 2026-07-24 14:25:01 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...

# %% [markdown]
# The index can be computed with a simple method. A months window different from the default (3 months) can be set. The result is stored in the `index` attribute of the class.

# %%
enso_dataset.compute_index()
enso_obs.compute_index()
# Out:
# 2026-07-24 14:25:03 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions
# 2026-07-24 14:25:05 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon', 'lat'] dimensions

# %% [markdown]
# We can use the generic purpose method `save_netcdf` to save the index.

# %%
enso_dataset.save_netcdf(enso_dataset.index, diagnostic="enso", diagnostic_product="index")
enso_obs.save_netcdf(enso_obs.index, diagnostic="enso", diagnostic_product="index")
# Out:
# 2026-07-24 14:25:38 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-07-24 14:25:38 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/enso.index.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.nc
# 2026-07-24 14:25:38 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-07-24 14:25:38 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/enso.index.obs.ERA5.era5.r1.nc

# %% [markdown]
# We then evaluate regression and correlation. By default this is done for the entire dataset, but a season can be selected with the `season` argument.
# By default the statistics is computed with the same variable as the index, but the `var` argument can be used to ask for another variable.

# %%
reg_data = enso_dataset.compute_regression()
reg_obs = enso_obs.compute_regression()

enso_dataset.save_netcdf(reg_data, diagnostic="enso", diagnostic_product="regression")
enso_obs.save_netcdf(reg_obs, diagnostic="enso", diagnostic_product="regression")
# Out:
# 2026-07-24 14:25:38 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-07-24 14:25:39 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/enso.regression.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.nc
# 2026-07-24 14:25:39 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-07-24 14:26:38 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/enso.regression.obs.ERA5.era5.r1.nc

# %% [markdown]
# ## Plot ENSO
#
# The `PlotENSO` class will take care of plotting the result of multiple dataset. It will be initialized with just the indexes, specifying what is a dataset and what is the reference to compare against.
#
# The class accept any xarray, but it will use attributes to create labels and other details. It may be needed the creation of new attributes if you want to use results that do not come from AQUA with this plot class.

# %%
plt = PlotENSO(indexes=enso_dataset.index, ref_indexes=enso_obs.index, loglevel="INFO")

# %% [markdown]
# The index plot is done with the `plot_index` method. Multiple panels are generated if multiple dataset are provided.

# %%
fig_index, _ = plt.plot_index()

# %% [markdown]
# We create the caption to be embedded with the metadata of the figure. We save the image as png but pdf is supported as well.

# %%
description = plt.set_index_description()
plt.save_plot(fig_index, diagnostic_product="index", metadata={"description": description})
# Out:
# 2026-07-24 14:26:39 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-07-24 14:26:39 :: OutputSaver :: INFO     -> Saved PNG: ./png/enso.index.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.png
# 2026-07-24 14:26:39 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2026-07-24 14:26:40 :: OutputSaver :: INFO     -> Saved PDF: ./pdf/enso.index.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.pdf
# 2026-07-24 14:26:40 :: create_folder :: INFO     -> Folder ./svg already exists
# 2026-07-24 14:26:40 :: OutputSaver :: INFO     -> Saved SVG: ./svg/enso.index.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.svg

# %% [markdown]
# We strongly suggest to load the regression and correlation datasets before giving them to the plot routines, since cartopy and dask do not perform very well together.

# %%
reg_data.load()
reg_obs.load()
# Out:
# <xarray.DataArray (lat: 721, lon: 1440)> Size: 8MB
# array([[            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        ...,
#        [-2.52989207e-05, -2.54730193e-05, -2.54730193e-05, ...,
#         -2.76327179e-05, -2.52989207e-05, -2.54730193e-05],
#        [-2.52989207e-05, -1.97565349e-05, -2.04939750e-05, ...,
#         -2.52989207e-05, -2.52989207e-05, -2.52989207e-05],
#        [-2.61890498e-05, -2.61890498e-05, -2.61890498e-05, ...,
#         -2.61890498e-05, -2.61890498e-05, -2.61890498e-05]],
#       shape=(721, 1440))
# Coordinates:
#   * lat      (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon      (lon) float64 12kB 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
# Attributes: (12/22)
#     units:               K
#     code:                34
#     table:               128
#     paramId:             262101
#     shortName:           linear_regression
#     cfVarName:           tos
#     ...                  ...
#     model:               ERA5
#     exp:                 era5
#     realization:         r1
#     timestamp:           2026-07-24 14:25:39
#     aqua_version:        1.0.0a6
#     long_name:           Linear regression of sea surface temperature with Ni...

# %% [markdown]
# Here we show an example of plot flow. The first method will create the figure and it will be enough for the notebook usage.
# However a description to be stored as metadata and a saving routine are available and shown in the following example.

# %%
fig_reg = plt.plot_maps(maps=[reg_data], ref_maps=[reg_obs], statistic="regression")
description = plt.set_map_description(maps=[reg_data], ref_maps=[reg_obs], statistic="regression")
plt.save_plot(fig_reg, diagnostic_product="regression", metadata={"description": description})
# Out:
# 2026-07-24 14:26:43 :: PlotENSO :: INFO     -> Map description: Linear regression of sea surface temperature with Niño 3.4 index for IFS-FESOM-5km baseline-hist (from 1990-01 to 2014-12) compared to ERA5 (from 1940-01 to 2024-12). Contours represent the model regression, while shading is the difference between the model and the reference.
# 2026-07-24 14:26:43 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-07-24 14:26:44 :: OutputSaver :: INFO     -> Saved PNG: ./png/enso.regression.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.png
# 2026-07-24 14:26:44 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2026-07-24 14:26:44 :: OutputSaver :: INFO     -> Saved PDF: ./pdf/enso.regression.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.pdf
# 2026-07-24 14:26:44 :: create_folder :: INFO     -> Folder ./svg already exists
# 2026-07-24 14:26:44 :: OutputSaver :: INFO     -> Saved SVG: ./svg/enso.regression.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.obs.ERA5.era5.svg

# %% [markdown]
# # NCAR comparison
#
# With the NAO index computed, we can compare with observational data from NCAR, to check if the index is computed correctly. NCAR data are available in the data folder available in this same folder.

# %%
import datetime

import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

ncar_path = "data/nina34.anom.txt"
enso_ncar = np.genfromtxt(ncar_path, skip_header=3, skip_footer=4)

year = enso_ncar[:, 0]
month_data = enso_ncar[:, 1:]
time = xr.cftime_range(start=str(int(year[0])), periods=12 * len(year), freq="MS", calendar="standard")
month_data = month_data.reshape(-1)
enso_ncar = xr.DataArray(month_data, coords=[time], dims=["time"], name="monthly_data")

time_vals = np.array(time.values)

# Convert to datetime objects
datetimes = [np.datetime64(t).astype(datetime.datetime) for t in time_vals]

# Plot with matplotlib
fig = plt.figure(figsize=(10, 3))
plt.plot(datetimes, enso_ncar.values, label="NCAR")

plt.xlim(datetime.datetime(1950, 1, 31, 0, 0), datetime.datetime(2020, 10, 31, 0, 0))

enso_obs.index.plot(label="ERA5")
plt.legend()
plt.title("ENSO index comparison over Time")
fig.tight_layout()

plt.show()
