# %%
import matplotlib.pyplot as plt
import xarray as xr
from IPython.display import FileLink, display
from PIL import Image
from pypdf import PdfReader

from aqua.diagnostics.base import OutputSaver

# %% [markdown]
# The cell below initializes an ``OutputSaver class`` instance with the specified parameters: ``diagnostic``, ``catalog``, ``model``, ``exp``, ``outputdir`` and ``loglevel``. This instance will be used for generating descriptive filenames for the output files.
#
# Many diagnostics are based on comparisons between two datasets, such as a model and a reference dataset.
# In those cases, the triplet ``catalog-model-experiment`` for the reference dataset should be specified as well in the OutputSaver constructor.

# %%
outputsaver = OutputSaver(
    diagnostic="biases",
    catalog="climatedt-phase1",
    model="IFS-NEMO",
    exp="historical-1990",
    catalog_ref="obs",
    model_ref="ERA5",
    exp_ref="era5",
    outputdir=".",
    loglevel="DEBUG",
)
# Out:
# 2026-08-26 13:04:14 :: OutputSaver :: DEBUG    -> Complete initialization with parameters: {'diagnostic': 'biases', 'catalog': 'climatedt-phase1', 'model': 'IFS-NEMO', 'exp': 'historical-1990', 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5'}

# %% [markdown]
# Let's now generate a filename based on provided parameters.
# The ``generate_name`` method of the ``OutputSaver`` class requires to specify the ``diagnostic_product``, i.e. the type of output generate by the diagnostic (e.g. gregoryplot, histogram, timeseries, biasmap ecc.)

# %%
outputsaver.generate_name(diagnostic_product="biasmap")
# Out:
# 2026-08-26 13:04:16 :: OutputSaver :: DEBUG    -> Generated filename: biases.biasmap.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5
# 'biases.biasmap.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5'

# %% [markdown]
# If not specified in the outputsaver constructor, the catalog-model-experiment triplets for the principale and the reference dataset can be specified in the ``generate_name`` method.

# %% [markdown]
# The user can also specify some extra parameters that will be added to the filename, such as ``variable``, ``region``, ``period``, ``pressure level`` etc.
# Extra-keys are not mandatory, but if specified, they will be added to the filename.
# They are completely free and can be used to add any kind of information that the user wants to have in the filename.

# %%
extra_keys = {"variable": "q", "plev": 180000}

outputsaver.generate_name(diagnostic_product="biasmap", extra_keys=extra_keys)
# Out:
# 2026-08-26 13:04:18 :: OutputSaver :: DEBUG    -> Generated filename: biases.biasmap.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000
# 'biases.biasmap.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000'

# %% [markdown]
# Let's save a NetCDF file:

# %%
data = xr.Dataset({"data": (("x", "y"), [[1, 2], [3, 4]])})

metadata = {
    "title": "Testing the saving of NetCDF files",
    "author": "OutputSaver",
    "description": "Demonstrating netCDF Metadata Addition",
    "history": "Created on 2023-10-01",
}

outputsaver.save_netcdf(data, "test", extra_keys=extra_keys, metadata=metadata)
# Out:
# 2026-08-26 13:04:21 :: OutputSaver :: DEBUG    -> Generated filename: biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000
# 2026-08-26 13:04:21 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-08-26 13:04:21 :: OutputSaver :: DEBUG    -> Available metadata: {'diagnostic': 'biases', 'diagnostic_product': 'test', 'catalog': 'climatedt-phase1', 'model': 'IFS-NEMO', 'exp': 'historical-1990', 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5', 'variable': 'q', 'plev': '180000', 'timestamp': '2026-08-26 13:04:21', 'aqua_version': '1.0.0', 'title': 'Testing the saving of NetCDF files', 'author': 'OutputSaver', 'description': 'Demonstrating netCDF Metadata Addition', 'history': 'Created on 2023-10-01'}
# 2026-08-26 13:04:21 :: OutputSaver :: DEBUG    -> Writing to netcdf ./netcdf/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.nc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/b/b382321/AQUA-diagnostics/notebooks/diagnostics/netcdf/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '30c49b73-d8cd-4438-93d8-ae793d53adb0']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[17], line 10
#       6     "description": "Demonstrating netCDF Metadata Addition",
#       7     "history": "Created on 2023-10-01",
#       8 }
#       9
# ---> 10 outputsaver.save_netcdf(data, "test", extra_keys=extra_keys, metadata=metadata)
#
# File ~/AQUA-diagnostics/aqua/diagnostics/base/output_saver.py:268, in OutputSaver.save_netcdf(self, dataset, diagnostic_product, rebuild, extra_keys, metadata, create_catalog_entry, dict_catalog_entry)
#     265     dataset.load()
#     266 self.logger.debug("Writing to netcdf %s", filepath)
# --> 268 dataset.to_netcdf(filepath)
#     270 # create catalog entry for netcdf file
#     271 if create_catalog_entry:
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/core/dataset.py:2187, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    2183         if encoding is None:
#    2184             encoding = {}
#    2185         from xarray.backends.writers import to_netcdf
#    2186
# -> 2187         return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2188             self,
#    2189             path,
#    2190             mode=mode,
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/writers.py:422, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#     419 else:
#     420     target = normalized_path  # type: ignore[assignment]
# --> 422 store = get_writable_netcdf_store(
#     423     target,
#     424     engine,
#     425     mode=mode,
#     426     format=format,
#     427     autoclose=autoclose,
#     428     invalid_netcdf=invalid_netcdf,
#     429     auto_complex=auto_complex,
#     430 )
#     431 if group is not None:
#     432     store = store.get_child_store(group)
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/writers.py:78, in get_writable_netcdf_store(target, engine, format, mode, autoclose, invalid_netcdf, auto_complex)
#      75 if auto_complex is not None:
#      76     kwargs["auto_complex"] = auto_complex
# ---> 78 return store_open(target, mode=mode, format=format, **kwargs)
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:529, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     525 else:
#     526     manager = CachingFileManager(
#     527         netCDF4.Dataset, filename, mode=mode, kwargs=kwargs, lock=lock
#     528     )
# --> 529 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:429, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     427 self._group = group
#     428 self._mode = mode
# --> 429 self.format = self.ds.data_model
#     430 self._filename = self.ds.filepath()
#     431 self.is_remote = is_remote_uri(self._filename)
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:538, in NetCDF4DataStore.ds(self)
#     536 @property
#     537 def ds(self):
# --> 538     return self._acquire()
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:532, in NetCDF4DataStore._acquire(self, needs_lock)
#     531 def _acquire(self, needs_lock=True):
# --> 532     with self._manager.acquire_context(needs_lock) as root:
#     533         ds = _nc4_require_group(root, self._group, self._mode)
#     534     return ds
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/file_manager.py:207, in CachingFileManager.acquire_context(self, needs_lock)
#     204 @contextmanager
#     205 def acquire_context(self, needs_lock: bool = True) -> Iterator[T_File]:
#     206     """Context manager for acquiring a file."""
# --> 207     file, cached = self._acquire_with_cache_info(needs_lock)
#     208     try:
#     209         yield file
#
# File /work/bb1153/b382321/miniforge3/envs/aqua-dev/lib/python3.14/site-packages/xarray/backends/file_manager.py:225, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     223     kwargs = kwargs.copy()
#     224     kwargs["mode"] = self._mode
# --> 225 file = self._opener(*self._args, **kwargs)
#     226 if self._mode == "w":
#     227     # ensure file doesn't get overridden when opened again
#     228     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
# -> 2521 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/netCDF4/_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
# -> 2158 'Could not get source, probably due dynamically evaluated source code.'
#
# PermissionError: [Errno 13] Permission denied: '/home/b/b382321/AQUA-diagnostics/notebooks/diagnostics/netcdf/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.nc'

# %%
xr.open_dataset("netcdf/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.nc")
# Out:
# <xarray.Dataset> Size: 32B
# Dimensions:  (x: 2, y: 2)
# Dimensions without coordinates: x, y
# Data variables:
#     data     (x, y) int64 32B ...
# Attributes: (12/17)
#     history:             \n2026-08-26 12:10:37 AQUA💧: Created on 2023-10-01;\n
#     diagnostic:          globalbiases
#     diagnostic_product:  test
#     catalog:             climatedt-phase1
#     model:               IFS-NEMO
#     exp:                 historical-1990
#     ...                  ...
#     plev:                180000
#     timestamp:           2026-08-26 12:10:37
#     aqua_version:        1.0.1
#     title:               Testing the saving of NetCDF files
#     author:              OutputSaver
#     description:         Demonstrating netCDF Metadata Addition

# %% [markdown]
# Let's now save a plot in PDF and png formats, adding also some metadata.

# %%
metadata = {
    "Title": "Sample PDF/png",
    "Author": "OutputSaver",
    "Subject": "Demonstrating PDF/png Metadata Addition",
}

fig, ax = plt.subplots()
ax.plot([0, 1], [0, 1])

outputsaver.save_figure(fig, "test", extra_keys=extra_keys, metadata=metadata, extension=["pdf", "png"])
# Out:
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Generated filename: globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000
# 2026-08-26 12:10:38 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Available metadata: {'diagnostic': 'globalbiases', 'diagnostic_product': 'test', 'catalog': 'climatedt-phase1', 'model': 'IFS-NEMO', 'exp': 'historical-1990', 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5', 'variable': 'q', 'plev': '180000', 'timestamp': '2026-08-26 12:10:38', 'aqua_version': '1.0.1', 'Title': 'Sample PDF/png', 'Author': 'OutputSaver', 'Subject': 'Demonstrating PDF/png Metadata Addition'}
# 2026-08-26 12:10:38 :: add_pdf_metadata :: DEBUG    -> Metadata added to PDF: ./pdf/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.pdf
# 2026-08-26 12:10:38 :: OutputSaver :: INFO     -> Saved PDF: ./pdf/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.pdf
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Generated filename: globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000
# 2026-08-26 12:10:38 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Available metadata: {'diagnostic': 'globalbiases', 'diagnostic_product': 'test', 'catalog': 'climatedt-phase1', 'model': 'IFS-NEMO', 'exp': 'historical-1990', 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5', 'variable': 'q', 'plev': '180000', 'timestamp': '2026-08-26 12:10:38', 'aqua_version': '1.0.1', 'Title': 'Sample PDF/png', 'Author': 'OutputSaver', 'Subject': 'Demonstrating PDF/png Metadata Addition'}
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: diagnostic = globalbiases
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: diagnostic_product = test
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: catalog = climatedt-phase1
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: model = IFS-NEMO
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: exp = historical-1990
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: realization = r1
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: catalog_ref = obs
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: model_ref = ERA5
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: exp_ref = era5
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: variable = q
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: plev = 180000
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: timestamp = 2026-08-26 12:10:38
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: aqua_version = 1.0.1
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: Title = Sample PDF/png
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: Author = OutputSaver
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Adding metadata: Subject = Demonstrating PDF/png Metadata Addition
# 2026-08-26 12:10:38 :: add_png_metadata :: DEBUG    -> Metadata added to PNG: ./png/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.png
# 2026-08-26 12:10:38 :: OutputSaver :: INFO     -> Saved PNG: ./png/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.png

# %% [markdown]
# Let's open the saved file to check that the metadata has been correctly added.
#
# As you can see, the aqua_version and the timestamp are default metadata always added automatically to the output files.

# %%
png_path = "png/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.png"
display(FileLink(png_path))
with Image.open(png_path) as image:
    png_metadata = image.info.copy()
png_metadata
# Out:
# /work/bb1153/b383755/csrc/AQUA-diagnostics/notebooks/diagnostics/png/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.q.180000.png
# {'diagnostic': 'globalbiases',
#  'diagnostic_product': 'test',
#  'catalog': 'climatedt-phase1',
#  'model': 'IFS-NEMO',
#  'exp': 'historical-1990',
#  'realization': 'r1',
#  'catalog_ref': 'obs',
#  'model_ref': 'ERA5',
#  'exp_ref': 'era5',
#  'variable': 'q',
#  'plev': '180000',
#  'timestamp': '2026-08-26 12:10:38',
#  'aqua_version': '1.0.1',
#  'Title': 'Sample PDF/png',
#  'Author': 'OutputSaver',
#  'Subject': 'Demonstrating PDF/png Metadata Addition'}

# %% [markdown]
# Let's now save the plot only in png format:

# %%
outputsaver.save_figure(fig, "test", metadata=metadata, extension="pdf")
pdf_path = "pdf/biases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.pdf"
display(FileLink(pdf_path))
{key.lstrip("/").lower(): value for key, value in PdfReader(pdf_path).metadata.items() if value is not None}
# Out:
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Generated filename: globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5
# 2026-08-26 12:10:38 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Available metadata: {'diagnostic': 'globalbiases', 'diagnostic_product': 'test', 'catalog': 'climatedt-phase1', 'model': 'IFS-NEMO', 'exp': 'historical-1990', 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5', 'timestamp': '2026-08-26 12:10:38', 'aqua_version': '1.0.1', 'Title': 'Sample PDF/png', 'Author': 'OutputSaver', 'Subject': 'Demonstrating PDF/png Metadata Addition'}
# 2026-08-26 12:10:38 :: add_pdf_metadata :: DEBUG    -> Metadata added to PDF: ./pdf/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.pdf
# 2026-08-26 12:10:38 :: OutputSaver :: INFO     -> Saved PDF: ./pdf/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.pdf
# /work/bb1153/b383755/csrc/AQUA-diagnostics/notebooks/diagnostics/pdf/globalbiases.test.climatedt-phase1.IFS-NEMO.historical-1990.r1.obs.ERA5.era5.pdf
# {'producer': 'pypdf',
#  'diagnostic': 'globalbiases',
#  'diagnostic_product': 'test',
#  'catalog': 'climatedt-phase1',
#  'model': 'IFS-NEMO',
#  'exp': 'historical-1990',
#  'realization': 'r1',
#  'catalog_ref': 'obs',
#  'model_ref': 'ERA5',
#  'exp_ref': 'era5',
#  'timestamp': '2026-08-26 12:10:38',
#  'aqua_version': '1.0.1',
#  'title': 'Sample PDF/png',
#  'author': 'OutputSaver',
#  'subject': 'Demonstrating PDF/png Metadata Addition'}

# %% [markdown]
# In some diagnostics we may want to do a multimodel or multireference comparison.
# In this case, the user can specify a list of catalog-model-experiment triplets for the reference dataset. To avoid too long filenames, the keyword ``multimodel`` or ``multiref`` will be used to indicate that the dataset is a list of triplets.
# Full information about the datasets will be stored in output file metadata.

# %%
outputsaver = OutputSaver(
    diagnostic="biases",
    catalog=["climatedt-phase1", "climatedt-phase1"],
    model=["IFS-NEMO", "ICON"],
    exp=["historical-1990", "historical-1990"],
    catalog_ref="obs",
    model_ref="ERA5",
    exp_ref="era5",
    outputdir=".",
    loglevel="DEBUG",
)
outputsaver.generate_name(diagnostic_product="test")
# Out:
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Complete initialization with parameters: {'diagnostic': 'globalbiases', 'catalog': ['climatedt-phase1', 'climatedt-phase1'], 'model': ['IFS-NEMO', 'ICON'], 'exp': ['historical-1990', 'historical-1990'], 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5'}
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Generated filename: globalbiases.test.multimodel.obs.ERA5.era5
# 'globalbiases.test.multimodel.obs.ERA5.era5'

# %% [markdown]
# The information about the datasets will not appear in the filename but it will be stored in the metadata of the output file, so that it can be easily retrieved later.

# %%
metadata = {
    "Title": "Sample PDF/png",
    "Author": "OutputSaver",
    "Subject": "Demonstrating PDF/png Metadata Addition",
}

fig, ax = plt.subplots()
ax.plot([0, 1], [0, 1])

outputsaver.save_figure(fig, "test", metadata=metadata, extension="pdf")
# Out:
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Generated filename: globalbiases.test.multimodel.obs.ERA5.era5
# 2026-08-26 12:10:38 :: create_folder :: INFO     -> Folder ./pdf already exists
# 2026-08-26 12:10:38 :: OutputSaver :: DEBUG    -> Available metadata: {'diagnostic': 'globalbiases', 'diagnostic_product': 'test', 'catalog': ['climatedt-phase1', 'climatedt-phase1'], 'model': ['IFS-NEMO', 'ICON'], 'exp': ['historical-1990', 'historical-1990'], 'realization': 'r1', 'catalog_ref': 'obs', 'model_ref': 'ERA5', 'exp_ref': 'era5', 'timestamp': '2026-08-26 12:10:38', 'aqua_version': '1.0.1', 'Title': 'Sample PDF/png', 'Author': 'OutputSaver', 'Subject': 'Demonstrating PDF/png Metadata Addition'}
# 2026-08-26 12:10:38 :: add_pdf_metadata :: DEBUG    -> Metadata added to PDF: ./pdf/globalbiases.test.multimodel.obs.ERA5.era5.pdf
# 2026-08-26 12:10:38 :: OutputSaver :: INFO     -> Saved PDF: ./pdf/globalbiases.test.multimodel.obs.ERA5.era5.pdf

# %%
pdf_path = "pdf/biases.test.multimodel.obs.ERA5.era5.pdf"
display(FileLink(pdf_path))
# Out:
# /work/bb1153/b383755/csrc/AQUA-diagnostics/notebooks/diagnostics/pdf/globalbiases.test.multimodel.obs.ERA5.era5.pdf
