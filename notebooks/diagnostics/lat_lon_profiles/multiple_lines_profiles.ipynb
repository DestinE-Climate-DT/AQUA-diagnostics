# %% [markdown]
# # LatLonProfiles diagnostic - Multiple lines profiles
#
# The aim of this diagnostic is to visualise latitudinal or longitudinal profiles of a certain variable. In addition, plots are allowed to have multiple lines and/or show the seasonal and annual means of the selected variable.
#
# Specifically, in this notebook we look at the code for example plots of a multiple lines zonal profiles (along with the reference data).

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start with the import of the classes `LatLonProfiles` and `PlotLatLonProfiles`:

# %%
from aqua.diagnostics.lat_lon_profiles import LatLonProfiles, PlotLatLonProfiles

# %matplotlib inline

# %% [markdown]
# We generate a number of dictionaries, `dataset_dict`, including the options for the data we want to plot in this notebook.
# A reference profile to be plotted along with the input dataset is optional. If chosen, `obs_dict` is necessary.
# Lastly, the dictionaries `common_dict` include the common features for both datasets (input and reference) in case of historical data and in case of future scenarios, such as start and end dates.
#
# In this notebook, we will look at climate model outputs coming from both ICON and IFS-NEMO, and from 1990 to 1999 (historical) and 2030-2039 (future scenarios)
#
# Dictionaries also contain the optional `region` parameter, to select a specific area of interest. List of available default regions are in the common file `AQUA-diagnostics/aquua/diagnostics/config/definitions/regions.yaml`.

# %%
dataset_dict_1 = {"catalog": "climatedt-gen2", "model": "ICON-5km", "exp": "baseline-hist", "source": "lra-r100-monthly"}

dataset_dict_2 = {"catalog": "climatedt-gen2", "model": "ICON-5km", "exp": "projections-ssp370", "source": "lra-r100-monthly"}

dataset_dict_3 = {"catalog": "climatedt-gen2", "model": "IFS-FESOM-5km", "exp": "baseline-hist", "source": "lra-r100-monthly"}

dataset_dict_4 = {
    "catalog": "climatedt-gen2",
    "model": "IFS-FESOM-5km",
    "exp": "projections-ssp370",
    "source": "lra-r100-monthly",
}

common_dict_hist = {"startdate": "1990-01-01", "enddate": "1999-12-31", "region": "europe", "loglevel": "info"}

common_dict_ssp = {"startdate": "2030-01-01", "enddate": "2039-12-31", "region": "europe", "loglevel": "info"}

obs_dict = {
    "catalog": "obs",
    "model": "ERA5",
    "exp": "era5",
    "source": "monthly",
    "std_startdate": "1990-01-01",
    "std_enddate": "1999-12-31",
}

# %% [markdown]
# We hence generate an object of the `LatLonProfiles` class for each line, and we decide to plot zonal profiles as an example. This means that the code will be performing the zonal mean, by averaging across the longitudes.
#
# The analysed variable for this notebook will be `tprate` (Total Precipitation Rate, expressed in mm/day).
#
# By default, the `mean_type` parameter in set as 'zonal' (so the profile will be zonal even without a specific `mean_type` setting), but to visualise the meridional profile, one can just set `mean_type='meridional'`. We also generate another LatLonProfiles object for the reference zonal profile.
#
# The `std=True` option computes the standard deviation and is optional. We set it as `True` for the ERA5 reference profile to enable uncertainty shading in plots via `ref_std_data`. While model data can also compute std, only reference std shading is directly supported for plotting simplicity.

# %%
lonlat_dataset_1 = LatLonProfiles(**dataset_dict_1, **common_dict_hist, mean_type="zonal")
lonlat_dataset_2 = LatLonProfiles(**dataset_dict_2, **common_dict_ssp)
lonlat_dataset_3 = LatLonProfiles(**dataset_dict_3, **common_dict_hist)
lonlat_dataset_4 = LatLonProfiles(**dataset_dict_4, **common_dict_ssp)

lonlat_obs = LatLonProfiles(**obs_dict, **common_dict_hist, mean_type="zonal")

run_dict = {"var": "tprate", "units": "mm/day"}

lonlat_dataset_1.run(**run_dict)
lonlat_dataset_2.run(**run_dict)
lonlat_dataset_3.run(**run_dict)
lonlat_dataset_4.run(**run_dict)

lonlat_obs.run(**run_dict, std=True)
# Out:
# 2026-06-21 18:33:52 :: LatLonProfiles :: INFO     -> Region Europe found, using lon: [-10, 40], lat: [35, 70]
# 2026-06-21 18:33:52 :: LatLonProfiles :: INFO     -> Region Europe found, using lon: [-10, 40], lat: [35, 70]
# 2026-06-21 18:33:52 :: LatLonProfiles :: INFO     -> Region Europe found, using lon: [-10, 40], lat: [35, 70]
# 2026-06-21 18:33:52 :: LatLonProfiles :: INFO     -> Region Europe found, using lon: [-10, 40], lat: [35, 70]
# 2026-06-21 18:33:53 :: LatLonProfiles :: INFO     -> Region Europe found, using lon: [-10, 40], lat: [35, 70]
# 2026-06-21 18:33:53 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-06-21 18:33:53 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-06-21 18:33:53 :: ConfigPath :: INFO     -> ICON-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-06-21 18:33:53 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-06-21 18:33:53 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-06-21 18:33:53 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-06-21 18:33:53 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-06-21 18:33:53 :: Reader :: INFO     -> Regridder() cannot init with the provided grid metadata: trying with data
# 2026-06-21 18:34:04 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:04 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:34:04 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:04 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-06-21 18:34:04 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-06-21 18:34:04 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_ICON-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-06-21 18:34:04 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-06-21 18:34:04 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:04 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-06-21 18:34:15 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-06-21 18:34:15 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-06-21 18:34:15 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-06-21 18:34:15 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:15 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:15 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:15 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:34:16 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:34:16 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:16 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:16 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.djf.tprate.europe.nc
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:16 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:16 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.mam.tprate.europe.nc
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:16 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:16 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.jja.tprate.europe.nc
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:16 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:16 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.seasonal.son.tprate.europe.nc
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:16 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:16 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-06-21 18:34:17 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:17 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-06-21 18:34:17 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:17 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:17 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.longterm.tprate.europe.nc
# 2026-06-21 18:34:17 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-06-21 18:34:17 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-06-21 18:34:17 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-06-21 18:34:17 :: ConfigPath :: INFO     -> ICON-5km_projections-ssp370_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-06-21 18:34:17 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-06-21 18:34:17 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-06-21 18:34:17 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-06-21 18:34:17 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-06-21 18:34:17 :: Reader :: INFO     -> Regridder() cannot init with the provided grid metadata: trying with data
# 2026-06-21 18:34:27 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:34:27 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:27 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:34:27 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:27 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-06-21 18:34:27 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-06-21 18:34:27 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_ICON-5km_projections-ssp370_lra-r100-monthly.nc.
# 2026-06-21 18:34:27 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-06-21 18:34:27 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:27 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-06-21 18:34:34 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-06-21 18:34:34 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-06-21 18:34:34 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-06-21 18:34:34 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:34 :: LatLonProfiles :: INFO     -> Start date: 2030-01-01
# 2026-06-21 18:34:34 :: LatLonProfiles :: INFO     -> End date: 2039-12-31
# 2026-06-21 18:34:35 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-06-21 18:34:35 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-06-21 18:34:35 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:35 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:35 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:35 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:34:35 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:34:35 :: timmean_chunking :: INFO     -> 120 chunks from 2030-01-01 00:00:00 to 2039-12-01 00:00:00 at MS frequency to be analysed
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.djf.tprate.europe.nc
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.mam.tprate.europe.nc
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.jja.tprate.europe.nc
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.seasonal.son.tprate.europe.nc
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:36 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-06-21 18:34:36 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:36 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:36 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.ICON-5km.projections-ssp370.r1.longterm.tprate.europe.nc
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-06-21 18:34:36 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-06-21 18:34:36 :: ConfigPath :: INFO     -> IFS-FESOM-5km_baseline-hist_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-06-21 18:34:36 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-06-21 18:34:36 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-06-21 18:34:36 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-06-21 18:34:36 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-06-21 18:34:36 :: Reader :: INFO     -> Regridder() cannot init with the provided grid metadata: trying with data
# 2026-06-21 18:34:45 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:34:45 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:45 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:34:45 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:34:45 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-06-21 18:34:45 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-06-21 18:34:45 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_baseline-hist_lra-r100-monthly.nc.
# 2026-06-21 18:34:45 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-06-21 18:34:45 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:45 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-06-21 18:34:53 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-06-21 18:34:53 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-06-21 18:34:53 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-06-21 18:34:53 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:53 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:34:53 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:53 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:34:53 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:34:53 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:54 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:54 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.djf.tprate.europe.nc
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:54 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:54 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.mam.tprate.europe.nc
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:54 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:54 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.jja.tprate.europe.nc
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:54 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:54 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.seasonal.son.tprate.europe.nc
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:34:54 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-06-21 18:34:54 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-06-21 18:34:54 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:34:54 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.baseline-hist.r1.longterm.tprate.europe.nc
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-06-21 18:34:54 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-06-21 18:34:54 :: ConfigPath :: INFO     -> IFS-FESOM-5km_projections-ssp370_lra-r100-monthly triplet found in in climatedt-gen2!
# 2026-06-21 18:34:55 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-06-21 18:34:55 :: FixerConfigure :: INFO     -> No fixer_name found, only convention will be applied
# 2026-06-21 18:34:55 :: Reader :: INFO     -> Grid metadata is lon-lat
# 2026-06-21 18:34:55 :: Regridder :: WARNING  -> Source grid path not found. Please provide a dataset.
# 2026-06-21 18:34:55 :: Reader :: INFO     -> Regridder() cannot init with the provided grid metadata: trying with data
# 2026-06-21 18:35:33 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:35:33 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:35:33 | smmregrid.GridInspect |     INFO -> Updating the log_level to INFO
# 2026-06-21 18:35:33 | smmregrid.GridInspect |     INFO -> Data is already an xarray Dataset or DataArray
# 2026-06-21 18:35:33 :: Regridder :: INFO     -> Using provided dataset as a grid path for 2d
# 2026-06-21 18:35:33 :: Regridder :: INFO     -> Grid name: lon-lat
# 2026-06-21 18:35:33 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_IFS-FESOM-5km_projections-ssp370_lra-r100-monthly.nc.
# 2026-06-21 18:35:33 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-06-21 18:35:33 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:35:33 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-06-21 18:35:45 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': [260048, 235055, 172228, 228, 'mtpr', 'tprate', 'avg_tprate', 'prec', 'tp', 'TP', 'rr', 'pr'], 'grib': 260048}}
# 2026-06-21 18:35:45 :: Fixer :: INFO     -> tprate: converting units kg m**-2 s**-1 --> kg m**-2 s**-1
# 2026-06-21 18:35:45 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-06-21 18:35:45 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> Start date: 2030-01-01
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> End date: 2039-12-31
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:35:45 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:35:45 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:35:45 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:35:45 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:35:45 :: timmean_chunking :: INFO     -> 120 chunks from 2030-01-01 00:00:00 to 2039-12-01 00:00:00 at MS frequency to be analysed
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-06-21 18:35:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:35:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.djf.tprate.europe.nc
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-06-21 18:35:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:35:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.mam.tprate.europe.nc
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-06-21 18:35:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:35:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.jja.tprate.europe.nc
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-06-21 18:35:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:35:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.seasonal.son.tprate.europe.nc
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:35:46 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-06-21 18:35:46 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-06-21 18:35:46 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:35:46 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.climatedt-gen2.IFS-FESOM-5km.projections-ssp370.r1.longterm.tprate.europe.nc
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Running LatLonProfiles for tprate
# 2026-06-21 18:35:46 :: LatLonProfiles :: INFO     -> Retrieving data for variable tprate
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:173: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/intake/catalog/utils.py:182: UserWarning: Shell command not executed due to getshell=False
#   warnings.warn("Shell command not executed due to getshell=False")
# 2026-06-21 18:35:46 :: ConfigPath :: INFO     -> ERA5_era5_monthly triplet found in in obs!
# 2026-06-21 18:35:47 :: FixerConfigure :: INFO     -> Convention dictionary: eccodes-2.39.0
# 2026-06-21 18:35:47 :: FixerConfigure :: INFO     -> Fix names in metadata is ERA5-destine-v1
# 2026-06-21 18:35:47 :: FixerConfigure :: INFO     -> Fix names ERA5-destine-v1 found in fixes files
# 2026-06-21 18:35:47 :: Reader :: INFO     -> Grid metadata is era5-r025s
# 2026-06-21 18:35:47 :: Regridder :: INFO     -> Grid name: era5-r025s
# 2026-06-21 18:35:47 :: Regridder :: INFO     -> Loading existing source area from /work/bb1153/b382289/data/aqua-dvc/areas/cell_area_era5-r025s.nc.
# 2026-06-21 18:35:47 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Coordinate time not found in source coordinates.
# 2026-06-21 18:35:47 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:35:47 :: Reader :: INFO     -> Retrieving variables: ['tprate']
# 2026-06-21 18:35:49 :: Fixer :: INFO     -> Variables to be fixed: {'tprate': {'source': 'TP', 'grib': 260048, 'src_units': 'm/day'}}
# 2026-06-21 18:35:49 :: Fixer :: INFO     -> tprate: converting units m/day --> kg m**-2 s**-1
# 2026-06-21 18:35:49 :: DataModel :: INFO     -> Applying data model: aqua
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Grid type: Regular
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Target data model: aqua
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Analysing coordinate: latitude
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Flipping coordinate lat from decreasing to increasing
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Analysing coordinate: longitude
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Coordinate isobaric not found in source coordinates.
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Coordinate depth not found in source coordinates.
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Analysing coordinate: time
# 2026-06-21 18:35:49 :: CoordTransformer :: INFO     -> Coordinate height not found in source coordinates.
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> Start date: 1990-01-01
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> End date: 1999-12-31
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> Mean type set to zonal
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> Computing temporal means
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:35:49 :: LatLonProfiles :: INFO     -> Computing seasonal mean
# 2026-06-21 18:35:49 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:35:49 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:35:49 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:35:49 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# 2026-06-21 18:36:06 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-06-21 18:36:06 :: LatLonProfiles :: INFO     -> Computing seasonal standard deviation
# 2026-06-21 18:36:06 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:36:06 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:36:06 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:36:06 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 2026-06-21 18:36:10 :: LatLonProfiles :: INFO     -> Saving seasonal netcdf file
# 2026-06-21 18:36:10 :: LatLonProfiles :: INFO     -> Saving DJF data for zonal_profile to netcdf in ./
# 2026-06-21 18:36:10 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:10 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.tprate.europe.nc
# 2026-06-21 18:36:10 :: LatLonProfiles :: INFO     -> Saving MAM data for zonal_profile to netcdf in ./
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.tprate.europe.nc
# 2026-06-21 18:36:11 :: LatLonProfiles :: INFO     -> Saving JJA data for zonal_profile to netcdf in ./
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.tprate.europe.nc
# 2026-06-21 18:36:11 :: LatLonProfiles :: INFO     -> Saving SON data for zonal_profile to netcdf in ./
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.tprate.europe.nc
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.djf.std.tprate.europe.nc
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.mam.std.tprate.europe.nc
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.jja.std.tprate.europe.nc
# 2026-06-21 18:36:11 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:11 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.seasonal.son.std.tprate.europe.nc
# 2026-06-21 18:36:11 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:36:11 :: LatLonProfiles :: INFO     -> Computing longterm mean
# 2026-06-21 18:36:11 :: TimStat :: INFO     -> Resampling to None frequency and computing mean...
# 2026-06-21 18:36:11 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:36:14 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-06-21 18:36:14 :: LatLonProfiles :: INFO     -> Computing longterm standard deviation
# 2026-06-21 18:36:14 :: FldStat :: INFO     -> Computing area-weighted mean on ['lon'] dimensions
# 2026-06-21 18:36:14 :: TimStat :: INFO     -> Resampling to MS frequency and computing mean...
# 2026-06-21 18:36:15 :: TimStat :: INFO     -> Checking if incomplete chunks has been produced...
# 2026-06-21 18:36:15 :: timmean_chunking :: INFO     -> 120 chunks from 1990-01-01 00:00:00 to 1999-12-01 00:00:00 at MS frequency to be analysed
# /home/b/b383197/miniforge3/envs/aqua-dev/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 2026-06-21 18:36:19 :: LatLonProfiles :: INFO     -> Saving longterm netcdf file
# 2026-06-21 18:36:19 :: LatLonProfiles :: INFO     -> Saving longterm data for zonal_profile to netcdf in ./
# 2026-06-21 18:36:19 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:19 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.tprate.europe.nc
# 2026-06-21 18:36:19 :: create_folder :: INFO     -> Folder ./netcdf already exists
# 2026-06-21 18:36:19 :: OutputSaver :: INFO     -> Saved NetCDF: ./netcdf/latlonprofile.zonal_profile.obs.ERA5.era5.r1.longterm.std.tprate.europe.nc
# 2026-06-21 18:36:19 :: LatLonProfiles :: INFO     -> LatLonProfiles computation completed

# %% [markdown]
# Different types of dataset can be managed and plotted via `LatLonProfiles` and `PlotLatLonProfiles`:
# - Seasonal mean, with season choice between DJF, MAM, JJA and SON
# - Annual mean
#
# ## Single plot - Seasonal means
#
# LatLonProfiles objects include the seasonal mean for each season. For this example, we plot the winter DJF means (selected via the [0] option), along with the winter ERA5 reference data as well as the standard deviation shadings.
#
# Standard deviation shading is enabled for the ERA5 reference data via `ref_std_data`, providing uncertainty bands that aid in model validation. The plotting code follows:

# %%
# Use seasonal data (DJF - winter as example)
multi_line_plot = PlotLatLonProfiles(
    data=[
        lonlat_dataset_1.seasonal[0],  # ICON tprate - DJF 1990-1999
        lonlat_dataset_2.seasonal[0],  # ICON tprate - DJF 2030-2039
        lonlat_dataset_3.seasonal[0],  # IFS-NEMO tprate - DJF 1990-1999
        lonlat_dataset_4.seasonal[0],
    ],  # IFS-NEMO tprate - DJF 2030-2039
    ref_data=lonlat_obs.seasonal[0],  # ERA5 Reference tprate - DJF 1990-1999
    data_type="longterm",
    ref_std_data=lonlat_obs.std_seasonal[0],  # DJF std for ERA5 Reference tprate
    loglevel="INFO",
)

title = "DJF Total precipitation rate comparison in the past and in the future for CMIP6 models"
multi_line_plot.run(show=True, format="png")
# Out:
# 2026-06-21 18:36:20 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-06-21 18:36:20 :: PlotLatLonProfiles :: INFO     -> Description: Climatological zonal profile of total precipitation rate over Europe for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-06-21 18:36:20 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-06-21 18:36:21 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.europe.png
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# We hence use the PlotLatLonProfiles class to finalise the example plots, starting from the annual means and concluding with the seasonal means.
#
# ## Single plot - Annual means
#
# The logic is the same as the previous plot, only changing the `.seasonal` object with `.longterm`:

# %%
# Create separate annual plot for multi-data
annual_multi_data = [
    lonlat_dataset_1.longterm,  # ICON tprate - 1990-1999
    lonlat_dataset_2.longterm,  # ICON tprate - 2030-2039
    lonlat_dataset_3.longterm,  # IFS-NEMO tprate - 1990-1999
    lonlat_dataset_4.longterm,  # IFS-NEMO tprate - 2030-2039
]

annual_multi_plot = PlotLatLonProfiles(
    data=annual_multi_data,
    ref_data=lonlat_obs.longterm,
    data_type="longterm",
    ref_std_data=lonlat_obs.std_annual,  # Annual std for ERA5 Reference tprate
    loglevel="INFO",
)

# Run the annual multi plot
annual_multi_plot.run(show=True, format="png")
# Out:
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> Description: Climatological zonal profile of total precipitation rate over Europe for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-06-21 18:36:21 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-06-21 18:36:21 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.europe.png
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully

# %% [markdown]
# ## Multiple plot - Seasonal mean profiles
#
# As for the annual mean plot, same logic applies also for seasonal profiles:

# %%
# Prepare model data for 4 seasons
combined_seasonal_model_data = []
combined_seasonal_ref_data = []

for i in range(4):  # DJF, MAM, JJA, SON
    combined_seasonal_model_data.append(
        [
            lonlat_dataset_1.seasonal[i],  # ICON tprate - 1990-1999 - season i
            lonlat_dataset_2.seasonal[i],  # ICON tprate - 2030-2039 - season i
            lonlat_dataset_3.seasonal[i],  # IFS-NEMO tprate - 1990-1999 - season i
            lonlat_dataset_4.seasonal[i],  # IFS-NEMO tprate - 2030-2039 - season i
        ]
    )
    combined_seasonal_ref_data.append(lonlat_obs.seasonal[i])

# Prepare std data for reference only
multi_ref_std_data = [lonlat_obs.std_seasonal[i] for i in range(4)]

# Create 4-panel seasonal plot with multiple variables
seasonal_multi_plot = PlotLatLonProfiles(
    data=combined_seasonal_model_data,
    ref_data=combined_seasonal_ref_data,
    ref_std_data=multi_ref_std_data,
    data_type="seasonal",
    loglevel="INFO",
)

# Run the seasonal plot (multi_var_labels is already defined in the previous cell)
seasonal_multi_plot.run(show=True, format="png")
# Out:
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> Running PlotLatLonProfiles
# 2026-06-21 18:36:21 :: PlotLatLonProfiles :: INFO     -> Description: Seasonal zonal profile of total precipitation rate over Europe for ICON-5km baseline-hist, ICON-5km projections-ssp370, IFS-FESOM-5km baseline-hist and IFS-FESOM-5km projections-ssp370 from 1990-01 to 1999-12 compared to ERA5 era5 with ±2σ uncertainty bands (from 1990-01 to 1999-12).
# 2026-06-21 18:36:21 :: create_folder :: INFO     -> Folder ./png already exists
# 2026-06-21 18:36:22 :: OutputSaver :: INFO     -> Saved PNG: ./png/lat_lon_profiles.seasonal_zonal_profile.climatedt-gen2.ICON-5km.baseline-hist.r1.tprate.europe.png
# 2026-06-21 18:36:23 :: PlotLatLonProfiles :: INFO     -> PlotLatLonProfiles completed successfully
